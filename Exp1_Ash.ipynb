# %%
#To Read,display the image
import cv2
from google.colab.patches import cv2_imshow
a = cv2.imread('Buggati.jpg',1)
cv2_imshow(a)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=751x371 at 0x7F5DB81358E0>
# -1

# %%
#To write the image
colorImage = cv2.imread('Buggati.jpg',1)
cv2.imwrite('written.jpg',colorImage)
writtenImage = cv2.imread('written.jpg',1)
cv2_imshow(writtenImage)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=751x371 at 0x7F5DE8305DC0>
# -1

# %%
#Find the shape of the Image
import cv2 
colorImage = cv2.imread('Buggati.jpg',1)
print(colorImage.shape)
# Out:
# (371, 751, 3)

# %%
#To access rows and columns
import random
colorImage = cv2.imread('Buggati.jpg',1)
for i in range(100):
    for j in range(colorImage.shape[1]):
        colorImage[i][j]=[random.randint(0,255),random.randint(0,255),random.randint(0,255)]
cv2_imshow(colorImage)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=751x371 at 0x7F5DE8305BB0>
# -1

# %%
#To cut and paste portion of image
color_img = cv2.imread('Buggati.jpg',1)
tag = color_img[200:400,300:500]
color_img[200:400,100:300] = tag
cv2_imshow(color_img)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=751x371 at 0x7F5DB81352B0>
# -1
